# %%
from bs4 import BeautifulSoup
import requests
import json
import pandas as pd
from operator import itemgetter as iget
from itertools import accumulate

# %%
def load_json(filename):
    with open(filename,encoding='utf-8') as f:
        d = json.load(f)
    return d

kanji2element = load_json("kanjivg-radical-master/data/kanji2element.json")
element2kanji = load_json("kanjivg-radical-master/data/element2kanji.json")

url = 'https://vacuum.name/japanese/wanikani/radicals'

page = requests.get(url)
soup = BeautifulSoup(page.text)

radicals = [res.text.split() for res in soup.find_all('div',class_ = 'group rounded bg-radical')]
radicals_to_meaning = {elem[0]:elem[1] for elem in radicals if len(elem) != 1}
radicals = [elem[0] for elem in radicals_to_meaning]
json.dump(radicals_to_meaning,open('dump.json','w'))

kanji_freq = json.load(open('data/twitter.json','r',encoding='utf-8'))
kanji_freq = {el[0]:el[2] for el in kanji_freq}

url_wiki = 'https://ru.wikipedia.org/wiki/Список_дзёё_кандзи'

page = requests.get(url_wiki)
soup = BeautifulSoup(page.text)

def get_table_lines(soup):
    for el in soup.find('table',class_='sortable wikitable').find_all('tr'):
        yield [res.text.strip() for res in el.find_all('td')]

lines = sorted([el+[kanji_freq[el[1]] if el[1] in kanji_freq else 0] for el in get_table_lines(soup) if len(el) != 0],key=iget(9),reverse=True)

kanji = pd.DataFrame(lines,columns=['id','kanji','old','radical','strokes','grade','year added','meaning','readings','freq'])
kanji = kanji.drop(columns='id')
kanji['freq'] = kanji['kanji'].apply(lambda k : kanji_freq[k]
                                     if k in kanji_freq else 0)

radical_freq = kanji.groupby('radical').freq.agg(freq = 'sum').sort_values('freq',ascending=False)
freq = list(radical_freq['freq'])
sum_freq = list(accumulate(freq))
radical_freq['sum'] = sum_freq
radical_to_freq = {index : row['freq'] for index, row in radical_freq.iterrows()}

with open('data/variants.txt','r',encoding='utf-8') as file:
    lines = [line[:-1].split('\t')[1:] for line in file]
    
radicals = pd.DataFrame(lines,columns=['radical (variants)','strokes','meaning and reading','freq','jfreq','examples','group'])
radicals['radical'] = radicals['radical (variants)'].apply(lambda s : s[0])

def get_variants(s : str):
    if (len(s) == 1):
        return ''
    l = s[3:-1].split(',')
    return ''.join(l)

radicals['variants'] = radicals['radical (variants)'].apply(get_variants)
radicals = radicals.drop(columns='radical (variants)')
radicals = radicals[['radical', 'variants','strokes','meaning and reading','freq','jfreq','examples','group']]
radicals['kfreq'] = radicals['freq'].apply(lambda s : int(s.replace(',','')) if s != '' else 0)
radicals['freq'] = radicals['radical'].apply(lambda s : radical_to_freq[s] if s in radical_to_freq else 0)

# %%
radicals.sort_values('freq',ascending=False)[50:100]
# Out:
#     radical variants strokes                              meaning and reading  \
# 158       車                7                          cart, car (くるま, kuruma)
# 99        生                5                             life (うまれる, umareru)
# 9         儿                2       legs, human underneath (にんにょう, ninnyō, 人繞)
# 114       禾                5                   two-branch tree (のぎ, nogi, ノ木)
# 103       疒                5                  sickness (やまいだれ, yamaidare, 病垂)
# 23        十                2                       ten, complete (じゅう, jū, 十)
# 43        尸                3                      corpse (しかばね, shikabane, 屍)
# 166       金        釒       8                           metal, gold (かね, kane)
# 69        方                4                       way, square, raft (ほう, hō)
# 188       高        髙      10                          tall, high (たかい, takai)
# 122       羊       ⺶⺷       6                             sheep (ひつじ, hitsuji)
# 68        斤                4                                 axe (おの, ono, 斧)
# 131       自                6                         oneself (みずから, mizukara)
# 155       走        赱       7                               run (はしる, hashiru)
# 165       里                7                         village, mile (さと, sato)
# 105       白                5                                white (しろ, shiro)
# 28        又                2                     again, right hand (また, mata)
# 144       衣        衤       6                            clothes (ころも, koromo)
# 46        巛       川巜       3                                 river (かわ, kawa)
# 127       耳                6                                   ear (みみ, mimi)
# 75        欠                4                          yawn, lack (あくび, akubi)
# 3         丿                1          bend, possessive particle no (の, no, ノ)
# 40        寸                3              sun (unit of measurement) (すん, sun)
# 61        戈                4                  spear, halberd (かのほこ, kanohoko)
# 41        小      ⺌ ⺍       3         small, insignificant (ちいさい, chīsai, 小さい)
# 110       矢                5                                    arrow (や, ya)
# 6         二                2                                   two (に, ni, 二)
# 137       艮                6                    stopping (うしとら, ushitora, 丑寅)
# 111       石                5                                 stone (いし, ishi)
# 11        八        ハ       2      eight, eight-head (はちがしら, hachigashira, 八頭)
# 20        匕                2                   spoon hi (さじのひ, sajinohi, 匕のヒ)
# 92        牛      牜 ⺧       4                                   cow (うし, ushi)
# 151       豕                7                             pig (いのこ, inoko, 猪子)
# 187       骨               10                                  bone (ほね, hone)
# 171       隹                8                    old bird (ふるとり, furutori, 古鳥)
# 156       足        ⻊       7                                  foot (あし, ashi)
# 116       立                5                         stand, erect (たつ, tatsu)
# 115       穴                5                                   cave (あな, ana)
# 77        歹        歺       4                death, decay (がつへん, gatsuhen, 歹偏)
# 93        犬        犭       4                                    dog (いぬ, inu)
# 104       癶                5              footsteps (はつがしら, hatsugashira, 発頭)
# 167       長        镸       8         long, grow; leader (ながい-nagai; ちょう, chō)
# 163       酉                7  sake (rice-based alcoholic beverage) (とり, tori)
# 175       面        靣       9                                   face (めん, men)
# 181       風        𠘨       9                                  wind (かぜ, kaze)
# 25        卩        㔾       2                   seal (ふしづくり, fushidzukuri, 節旁)
# 26        厂                2                        cliff (がんだれ, gandare, 雁垂)
# 32        士                3             scholar, bachelor (さむらい, samurai, 侍)
# 79        毋       母⺟       4            do not; mother (なかれ-nakare; はは, haha)
# 123       羽                6                         feather, wing (はね, hane)
#
#          freq jfreq               examples    group  kfreq
# 158  0.005498                    軌 軟 較 軍 載             361
# 99   0.005450                        牲 笙 甥              22
# 9    0.005377                           兄元              52
# 114  0.005000              利 私 季 和 科 香 秦 穀             431
# 103  0.004969                    病 症 痛 癌 癖  Top 75%    526
# 23   0.004949    35                  十千午半博  Top 75%     55
# 43   0.004730                           尺局  Top 75%    148
# 166  0.004713        銀 銅 釘 銳 鋞 鋙 鉒 鉍 鉗 鈡 鈠  Top 50%    806
# 69   0.004663                      方 放 旅 族              92
# 188  0.004183                          髚 髛              34
# 122  0.004082                      着 羚 翔 着             156
# 68   0.003912                  斦 斧 新 斥 斬 斷              55
# 131  0.003775                      自 臫 臬 臲              34
# 155  0.003764                        赴 起 超             285
# 165  0.003732                          野 野              14
# 105  0.003704                      皃 的 皆 皇             109
# 28   0.003604                         友反取受              91
# 144  0.003462                衣 装 裁 (初 被 複)             607
# 46   0.003444                          川州巡              26
# 127  0.003426                      取 聞 職 叢             172
# 75   0.003419                    欣 欽 欧 欲 歌             235
# 3    0.003398                          久之乎              33
# 40   0.003129                         寸寺尊將  Top 75%     40
# 61   0.003099                         成式弐戦             116
# 41   0.002987                           小少              41
# 110  0.002918                        医 族 矩              64
# 6    0.002905                         五井些亞              29
# 137  0.002879                        良 飲 很               5
# 111  0.002859                  石 岩 砂 破 碑 碧  Top 75%    499
# 11   0.002804                         公六共兵              44
# 20   0.002749                           化北              19
# 92   0.002657                  告 牟 牧 物 特 解             233
# 151  0.002578                        豕 豚 象             148
# 187  0.002551                    骼 髒 髀 骿 骾             185
# 171  0.002411                  雀 集 雁 难 雀 雅             233
# 156  0.002397                    跑 跨 跟 跪 路             580
# 116  0.002288            立 音 産 翌 意 新 端 親 競             101
# 115  0.002211                空 突 窅 窘 窩 窶 竇             298
# 77   0.002171                        死 列 殕             231
# 93   0.002055                犬 犯 狂 狙 狗 献 獣  Top 75%    444
# 104  0.002017                          発 登              15
# 167  0.001990                            長              55
# 163  0.001947                    酒　醉 油 醒 酸  Top 75%    290
# 175  0.001745                          靦 靨              66
# 181  0.001703                    風 颱 飄 颿 颪             182
# 25   0.001663                          印危卵              40
# 26   0.001621                           厚原             129
# 32   0.001560                           士壹              24
# 79   0.001473                    毋 母 毎 姆 梅              16
# 123  0.001410                      習 翀 翁 翔             220

# %%
radical_freq.iloc[50:100]
# Out:
#              freq       sum
# radical
# 丨        0.005725  0.750173
# 肉        0.005662  0.755836
# 亅        0.005641  0.761477
# 干        0.005591  0.767068
# 車        0.005498  0.772566
# 生        0.005450  0.778016
# 儿        0.005377  0.783393
# 禾        0.005000  0.788393
# 疒        0.004969  0.793362
# 十        0.004949  0.798311
# 尸        0.004730  0.803040
# 金        0.004713  0.807754
# 方        0.004663  0.812417
# 高        0.004183  0.816599
# 羊        0.004082  0.820682
# 斤        0.003912  0.824594
# 自        0.003775  0.828368
# 走        0.003764  0.832132
# 里        0.003732  0.835864
# 白        0.003704  0.839568
# 又        0.003604  0.843172
# 衣        0.003462  0.846634
# 巛        0.003444  0.850078
# 耳        0.003426  0.853505
# 欠        0.003419  0.856924
# 丿        0.003398  0.860322
# 匸        0.003337  0.863659
# 寸        0.003129  0.866788
# 戈        0.003099  0.869887
# 小        0.002987  0.872874
# 戶        0.002949  0.875824
# 矢        0.002918  0.878741
# 二        0.002905  0.881646
# 艮        0.002879  0.884525
# 石        0.002859  0.887384
# 黑        0.002813  0.890197
# 八        0.002804  0.893001
# 匕        0.002749  0.895750
# 牛        0.002657  0.898406
# 豕        0.002578  0.900984
# 骨        0.002551  0.903535
# 老        0.002460  0.905996
# 隹        0.002411  0.908407
# 足        0.002397  0.910803
# 立        0.002288  0.913091
# 穴        0.002211  0.915302
# 歹        0.002171  0.917474
# 犬        0.002055  0.919529
# 襾        0.002044  0.921573
# 癶        0.002017  0.923590
