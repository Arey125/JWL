# %%
from bs4 import BeautifulSoup
import requests
import json

# %%
def load_json(filename):
    with open(filename) as f:
        d = json.load(f)
    return d

kanji2element = load_json("kanjivg-radical-master/data/kanji2element.json")
element2kanji = load_json("kanjivg-radical-master/data/element2kanji.json")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-4f2365df4235> in <module>
#       4     return d
#       5
# ----> 6 kanji2element = load_json("../data/kanji2element.json")
#       7 element2kanji = load_json("../data/element2kanji.json")
#
# <ipython-input-24-4f2365df4235> in load_json(filename)
#       1 def load_json(filename):
# ----> 2     with open(filename) as f:
#       3         d = json.load(f)
#       4     return d
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/kanji2element.json'

# %%
url = 'https://vacuum.name/japanese/wanikani/radicals'

# %%
page = requests.get(url)
soup = BeautifulSoup(page.text)

# %%
radicals = [res.text.split() for res in soup.find_all('div',class_ = 'group rounded bg-radical')]

# %%
len(radicals)
# Out:
# 227

# %%
len([elem[0] for elem in radicals if len(elem) == 1])
# Out:
# 18
